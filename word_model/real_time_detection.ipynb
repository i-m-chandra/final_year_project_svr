# %%
import serial 
import time
import csv

# %%
import numpy as np

# %%
from win32com.client import Dispatch
# Out:
# --------------------------------------------------------------------------
# ModuleNotFoundError                      Traceback (most recent call last)
# <ipython-input-3-0c2eac3a1407> in <module>
# ----> 1 from win32com.client import Dispatch
#
# ModuleNotFoundError: No module named 'win32com'

# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
model = load_model('svr_all_symbols.h5')
# Out:
# WARNING:tensorflow:From C:\Users\Puneet\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Puneet\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
ser = serial.Serial(port='COM13', baudrate=9600)

# %%
while True:
    print(ser.readline())

# %%
ser.close()

# %%
ser = serial.Serial(port='COM13', baudrate=9600)

# %%
speak = Dispatch("SAPI.SpVoice")

# %%
previous_word = ""
while True:
    data = ser.readline().decode("utf-8")
    lists = data.split(",")
    #print("lists is: ", lists)
    #print(len(lists))
    if(len(lists) == 14) :
        #print(lists)
        x_orient = float(lists[0])
        y_orient = float(lists[1])
        z_orient = float(lists[2])
        thumb = int(lists[3])/255.0
        index = int(lists[4])/255.0
        middle = int(lists[5])/255.0
        ring = int(lists[6])/255.0
        little = int(lists[7])/255.0
        touch = int(lists[8])/1023.0
        touch_index = int(lists[9])
        touch_middle = int(lists[10])
        touch_ring = int(lists[11])
        touch_little = int(lists[12])
        no_use = int(lists[13])
        
        real_time_array = np.array([x_orient, y_orient, z_orient, thumb, index, middle, ring, little, touch, touch_index,
                          touch_middle, touch_ring, touch_little, no_use])[0:13]
        #print(real_time_array.shape)
        #print(real_time_array)
        real_time_array = real_time_array.reshape(1, 13)
        
        prob_prediction = model.predict(real_time_array)
        predicted_label = np.argmax(prob_prediction)
        #print(predicted_label)
        
        word = ""
        
        a=0
        
        if predicted_label == 0:
            word = "hello"
        elif predicted_label == 1:
            word = "how"
        elif predicted_label == 2:
            word = "are"
        elif predicted_label == 3:
            word = "you ?"
        elif predicted_label == 4:
            word = "I am"
        elif predicted_label == 5:
            word = "fine."
        elif predicted_label == 6:
            word = "thank you!"
        elif predicted_label == 7:
            word = "working"
        elif predicted_label == 8:
            word = "on"
        elif predicted_label == 9:
            word = "idea"
        elif predicted_label == 10:
            word = "called"
        elif predicted_label == 11:
            word = "Good Morning"
        elif predicted_label == 12:
            word = "Sign and"
        elif predicted_label == 13:
            word = "voice"
        elif predicted_label == 14:
            word = "recognizer"
            
        if word == previous_word:
            # do nothing
            previous_word = word
        else:
            print("this is the label without threshold", word)
            print("probability is ", prob_prediction[0][predicted_label])
            if predicted_label == 4:
                if prob_prediction[0][predicted_label] > 0.5:
                    print(word)
                    previous_word = word
                    speak.Speak(word)
            elif predicted_label == 12:
                if prob_prediction[0][predicted_label] >0.6:
                    print(word)
                    previous_word = word
                    speak.Speak(word)
            elif predicted_label == 7:
                if prob_prediction[0][predicted_label] > 0.6:
                    print(word)
                    previous_word = word
                    speak.Speak(word)
            elif prob_prediction[0][predicted_label] > 0.65:
                print(word)
                previous_word = word
                speak.Speak(word)
# Out:
# this is the label without threshold Good Morning
# probability is  0.66456246
# Good Morning
# this is the label without threshold I am
# probability is  0.37801516
# this is the label without threshold how
# probability is  0.75657207
# how
# this is the label without threshold are
# probability is  0.34976068
# this is the label without threshold Good Morning
# probability is  0.91606593
# Good Morning
# this is the label without threshold hello
# probability is  0.9022044
# hello
# this is the label without threshold thank you!
# probability is  0.44609568
# this is the label without threshold fine.
# probability is  0.6238894
# this is the label without threshold Good Morning
# probability is  0.83150464
# Good Morning
# this is the label without threshold hello
# probability is  0.6630079
# hello
# this is the label without threshold are
# probability is  0.30571124
# this is the label without threshold how
# probability is  0.78678447
# how
# this is the label without threshold Good Morning
# probability is  0.52645135
# this is the label without threshold are
# probability is  0.8840272
# are
# this is the label without threshold recognizer
# probability is  0.6569677
# recognizer
# this is the label without threshold you ?
# probability is  0.90896094
# you ?
# this is the label without threshold recognizer
# probability is  0.435851
# this is the label without threshold Good Morning
# probability is  0.36614522
# this is the label without threshold are
# probability is  0.44655287
# this is the label without threshold I am
# probability is  0.5343716
# I am
# this is the label without threshold fine.
# probability is  0.34148243
# this is the label without threshold fine.
# probability is  0.8984103
# fine.
# this is the label without threshold thank you!
# probability is  0.90668523
# thank you!
# this is the label without threshold Good Morning
# probability is  0.31876212
# this is the label without threshold Good Morning
# probability is  0.5578589
# this is the label without threshold working
# probability is  0.91656196
# working
# this is the label without threshold on
# probability is  0.920868
# on
# this is the label without threshold working
# probability is  0.64399385
# working
# this is the label without threshold idea
# probability is  0.92587674
# idea
# this is the label without threshold called
# probability is  0.93627435
# called
# this is the label without threshold Good Morning
# probability is  0.78564566
# Good Morning
# this is the label without threshold Sign and
# probability is  0.54785764
# this is the label without threshold Sign and
# probability is  0.69294024
# Sign and
# this is the label without threshold Good Morning
# probability is  0.5093465
# this is the label without threshold Good Morning
# probability is  0.8051301
# Good Morning
# this is the label without threshold voice
# probability is  0.7285411
# voice
# this is the label without threshold are
# probability is  0.43037274
# this is the label without threshold are
# probability is  0.4054817
# this is the label without threshold recognizer
# probability is  0.52018946
# this is the label without threshold Good Morning
# probability is  0.5765005
# this is the label without threshold Good Morning
# probability is  0.41875377
# this is the label without threshold Good Morning
# probability is  0.4259428
# this is the label without threshold Good Morning
# probability is  0.45902017
# this is the label without threshold are
# probability is  0.30436042
# this is the label without threshold you ?
# probability is  0.2624889
# this is the label without threshold you ?
# probability is  0.43267182
# this is the label without threshold you ?
# probability is  0.42967647
# this is the label without threshold Good Morning
# probability is  0.40805596
# this is the label without threshold Good Morning
# probability is  0.5134161
# this is the label without threshold Good Morning
# probability is  0.47466975
# this is the label without threshold Good Morning
# probability is  0.497717
# this is the label without threshold Good Morning
# probability is  0.4228178
# this is the label without threshold Good Morning
# probability is  0.5550717
# this is the label without threshold Good Morning
# probability is  0.56713486
# this is the label without threshold Good Morning
# probability is  0.566937
# this is the label without threshold Good Morning
# probability is  0.6243538
# this is the label without threshold Good Morning
# probability is  0.6223888
# this is the label without threshold Good Morning
# probability is  0.63026595
# this is the label without threshold Good Morning
# probability is  0.4322633
# this is the label without threshold Good Morning
# probability is  0.799442
# Good Morning
# this is the label without threshold fine.
# probability is  0.3513171
# this is the label without threshold I am
# probability is  0.57117796
# I am
# this is the label without threshold Good Morning
# probability is  0.48044455
# this is the label without threshold you ?
# probability is  0.3669214
# this is the label without threshold you ?
# probability is  0.49767938
# this is the label without threshold are
# probability is  0.34549072
# this is the label without threshold hello
# probability is  0.8879846
# hello
# this is the label without threshold thank you!
# probability is  0.61631685
# this is the label without threshold Good Morning
# probability is  0.6792915
# Good Morning
# this is the label without threshold how
# probability is  0.753104
# how
# this is the label without threshold Good Morning
# probability is  0.44488266
# this is the label without threshold Good Morning
# probability is  0.58506703
# this is the label without threshold Good Morning
# probability is  0.64871275
# this is the label without threshold fine.
# probability is  0.3523558
# this is the label without threshold Good Morning
# probability is  0.9218427
# Good Morning
# this is the label without threshold I am
# probability is  0.3929686
# this is the label without threshold I am
# probability is  0.5465133
# I am
# this is the label without threshold working
# probability is  0.539219
# this is the label without threshold called
# probability is  0.46033522
# this is the label without threshold working
# probability is  0.5535439
# this is the label without threshold called
# probability is  0.25796184
# this is the label without threshold working
# probability is  0.9227049
# working
# this is the label without threshold are
# probability is  0.25484177
# this is the label without threshold are
# probability is  0.25694844
# this is the label without threshold are
# probability is  0.25845394
# this is the label without threshold are
# probability is  0.22071351
# this is the label without threshold Good Morning
# probability is  0.21293804
# this is the label without threshold Good Morning
# probability is  0.3924323
# this is the label without threshold Sign and
# probability is  0.4781077
# this is the label without threshold Sign and
# probability is  0.6671392
# Sign and
# this is the label without threshold voice
# probability is  0.7029076
# voice
# this is the label without threshold recognizer
# probability is  0.7446299
# recognizer
# this is the label without threshold are
# probability is  0.3176503
# this is the label without threshold Good Morning
# probability is  0.28258878
# this is the label without threshold are
# probability is  0.36877376
# this is the label without threshold Good Morning
# probability is  0.25277662
# this is the label without threshold Good Morning
# probability is  0.3104479
# this is the label without threshold Good Morning
# probability is  0.34055552
# this is the label without threshold Good Morning
# probability is  0.30291894
# this is the label without threshold Good Morning
# probability is  0.3332507
# this is the label without threshold Good Morning
# probability is  0.30550805
# this is the label without threshold how
# probability is  0.36997014
# this is the label without threshold Good Morning
# probability is  0.3168212
# this is the label without threshold Good Morning
# probability is  0.35147446
# this is the label without threshold how
# probability is  0.5019782
# this is the label without threshold I am
# probability is  0.33848497
# this is the label without threshold I am
# probability is  0.29138407
# this is the label without threshold I am
# probability is  0.31948245
# this is the label without threshold I am
# probability is  0.22797683
# this is the label without threshold I am
# probability is  0.33323607
# this is the label without threshold are
# probability is  0.22597636
# this is the label without threshold are
# probability is  0.3521484
# this is the label without threshold are
# probability is  0.3429917
# this is the label without threshold are
# probability is  0.3968127
# this is the label without threshold are
# probability is  0.35366753
# this is the label without threshold are
# probability is  0.38861176
# this is the label without threshold I am
# probability is  0.61608875
# I am
# this is the label without threshold are
# probability is  0.4281437
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-8-d62617eef3c6> in <module>
#       1 previous_word = ""
#       2 while True:
# ----> 3     data = ser.readline().decode("utf-8")
#       4     lists = data.split(",")
#       5     #print("lists is: ", lists)
#
# ~\Anaconda3\lib\site-packages\serial\serialwin32.py in read(self, size)
#     291                 if not result_ok:
#     292                     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
# --> 293                         raise SerialException("GetOverlappedResult failed ({!r})".format(ctypes.WinError()))
#     294                 read = buf.raw[:rc.value]
#     295             else:
#
# SerialException: GetOverlappedResult failed (PermissionError(13, 'Access is denied.', None, 5))
